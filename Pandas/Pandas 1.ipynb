# %% [markdown]
# ## Pandas

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\Ibad\Desktop\Cricket.csv")
df.head()
df.tail()
df.describe()
# Out:
#            Overs  Runs Given    Catches
# count  50.000000   50.000000  50.000000
# mean    3.012000   27.660000   0.720000
# std     0.978262   11.690935   0.881557
# min     1.000000    8.000000   0.000000
# 25%     2.125000   19.250000   0.000000
# 50%     3.000000   23.500000   0.000000
# 75%     4.000000   37.750000   1.000000
# max     4.000000   51.000000   3.000000

# %%
df[2:10] #slicing of rows
# Out:
#                    Stadium Team  Toss    Bat   Bowl Last Matches Performance  \
# 2                     OVAL  ZIM   WIN   True  False                      BAD
# 3             BUFFALO PARK  ZIM   WIN   True  False                    GOOD
# 4  NEWLANDS CRICKET GROUND   SL   WIN  False   True                   NORMAL
# 5                     OVAL  ENG  LOSS   True  False                     GOOD
# 6      SUPER SPORT STADIUM   WI   WIN  False   True                   NORMAL
# 7                MELBOURNE  AUS   WIN  False   True                      BAD
# 8                   LORD'S  AUS   WIN   True  False                      BAD
# 9                     OVAL  ENG  LOSS   True  False                   NORMAL
#
#   Last 3 Matches Performance Last 6 Matches Performance   Weather  Pitch  \
# 2                       GOOD                       GOOD  Overcast  GREEN
# 3                     NORMAL                     NORMAL  Overcast  DUSTY
# ...

# %%
df.columns
# Out:
# Index(['Stadium', 'Team', 'Toss', 'Bat', 'Bowl', 'Last Matches Performance',
#        'Last 3 Matches Performance', 'Last 6 Matches Performance', 'Weather',
#        'Pitch', 'Overs', 'Runs Given', 'Catches', 'Win OR Loss',
#        'Performance/Wickets'],
#       dtype='object')

# %%
df.Weather #df["Weather"] both for selecting columns
# Out:
# 0        Sunny
# 1        Sunny
# 2     Overcast
# 3     Overcast
# 4        Windy
# 5        Windy
# 6         Cool
# 7         Cool
# 8        Windy
# 9        Sunny
# 10       Windy
# 11        Cool
# 12        Cool
# 13    Overcast
# 14    Overcast
# 15       Sunny
# 16       Windy
# 17       Windy
# 18        Cool
# 19        Cool
# 20        Cool
# 21    Overcast
# 22    Overcast
# 23    Overcast
# 24       Sunny
# 25       Sunny
# 26    Overcast
# 27    Overcast
# 28        Cool
# 29        Cool
# 30        Cool
# 31       Sunny
# 32       Sunny
# 33        Cool
# 34        Cool
# 35    Overcast
# 36    Overcast
# 37       Windy
# 38       Sunny
# 39        Cool
# 40       Windy
# 41       Sunny
# 42       Windy
# 43       Sunny
# 44       Sunny
# 45       Sunny
# 46        Cool
# 47        Cool
# 48    Overcast
# 49    Overcast
# Name: Weather, dtype: object

# %%
df[["Weather","Pitch"]] #selecting multiple columns
# Out:
#    Weather  Pitch
# 0     Cool  DUSTY
# 1     Cool  GREEN
# 2     Cool  GREEN
# 3     Cool  DUSTY
# 4     Cool  DUSTY
# 5     Cool   DEAD
# 6     Cool   DEAD
# 7     Cool  GREEN
# 8     Cool  GREEN
# 9     Cool   DEAD
# 10    Cool   DEAD
# 11    Cool  DUSTY
# 12    Cool  DUSTY
# 13    Cool  GREEN
# 14    Cool  GREEN
# 15    Cool   DEAD
# 16    Cool    DRY
# 17    Cool  GREEN
# 18    Cool   DEAD
# 19    Cool  GREEN
# 20    Cool   DEAD
# 21    Cool  DUSTY
# 22    Cool  GREEN
# 23    Cool  GREEN
# 24    Cool  DUSTY
# 25    Cool  DUSTY
# 26    Cool   DEAD
# 27    Cool  GREEN
# 28    Cool    DRY
# 29    Cool    DRY
# 30    Cool  DUSTY
# 31    Cool   DEAD
# 32    Cool   DEAD
# 33    Cool   DEAD
# 34    Cool  GREEN
# 35    Cool  DUSTY
# 36    Cool   DEAD
# 37    Cool  GREEN
# 38    Cool  GREEN
# 39    Cool    DRY
# 40    Cool  GREEN
# 41    Cool  GREEN
# 42    Cool  GREEN
# 43    Cool   DEAD
# 44    Cool  GREEN
# 45    Cool  DUSTY
# 46    Cool  DUSTY
# 47    Cool    DRY
# 48    Cool  DUSTY
# ...

# %%
df["Runs Given"].max()
# Out:
# 51

# %%
df["Runs Given"].min()
# Out:
# 8

# %%
df[df.Pitch == str.upper("Dusty")] #select data using any condition
# Out:
#                     Stadium Team  Toss    Bat   Bowl Last Matches Performance  \
# 0               VCA STADIUM   WI  LOSS   True  False                     GOOD
# 3              BUFFALO PARK  ZIM   WIN   True  False                    GOOD
# 4   NEWLANDS CRICKET GROUND   SL   WIN  False   True                   NORMAL
# 11                   LORD'S  ENG   WIN  False   True                     GOOD
# 12              VCA STADIUM   SL   WIN   True  False                      BAD
# 21                EDGBASTON   NZ   WIN  False   True                     GOOD
# 24              VCA STADIUM  BAN   WIN   True  False                   NORMAL
# 25              VCA STADIUM  PAK   WIN   True  False                      BAD
# 30                EDGBASTON  AUS  LOSS  False   True                      BAD
# 35                   LORD'S  AUS   WIN  False   True                      BAD
# 45  NEWLANDS CRICKET GROUND  ENG  LOSS  False   True                     GOOD
# ...

# %%
df[df.Team == "IND"]
# Out:
#               Stadium Team  Toss    Bat   Bowl Last Matches Performance  \
# 19             LORD'S  IND  LOSS  False   True                   NORMAL
# 28  ROSE BOWL STADIUM  IND  LOSS  False   True                     GOOD
# 31    WANDERS STADIUM  IND   WIN  False   True                      BAD
# 46             LORD'S  IND  LOSS  False   True                     GOOD
# 49          MELBOURNE  IND   WIN   True  False                     GOOD
#
#    Last 3 Matches Performance Last 6 Matches Performance Weather  Pitch  \
# 19                        BAD                     NORMAL    Cool  GREEN
# 28                       GOOD                       GOOD    Cool    DRY
# 31                        BAD                     NORMAL    Cool   DEAD
# 46                        BAD                     NORMAL    Cool  DUSTY
# 49                       GOOD                     NORMAL    Cool    DRY
#
#     Overs  Runs Given  Catches Win OR Loss Performance/Wickets
# ...

# %%
df[df.Overs >= 3]
# Out:
#                     Stadium Team   Toss    Bat   Bowl  \
# 0               VCA STADIUM   WI   LOSS   True  False
# 1       SUPER SPORT STADIUM   SL  LOSS    True  False
# 2                      OVAL  ZIM    WIN   True  False
# 3              BUFFALO PARK  ZIM    WIN   True  False
# 4   NEWLANDS CRICKET GROUND   SL    WIN  False   True
# 5                      OVAL  ENG   LOSS   True  False
# 7                 MELBOURNE  AUS    WIN  False   True
# 9                      OVAL  ENG   LOSS   True  False
# 10  NEWLANDS CRICKET GROUND  ENG   LOSS  False   True
# 12              VCA STADIUM   SL    WIN   True  False
# 13          WANDERS STADIUM  BAN    WIN   True  False
# 15                   LORD'S  PAK   LOSS  False   True
# 16          WANDERS STADIUM   WI   LOSS   True  False
# 18                EDGBASTON   NZ   LOSS  False   True
# 19                   LORD'S  IND   LOSS  False   True
# 21                EDGBASTON   NZ    WIN  False   True
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.set_index("Stadium", inplace=True) #set index as any column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-f580d07419a9> in <module>
# ----> 1 df.set_index("Stadium", inplace=True) #set index as any column
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['Stadium'] are in the columns"

# %%
df.loc["OVAL"] #select rows using index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7412ff48a25> in <module>
# ----> 1 df.loc["OVAL"] #select rows using index
#
# NameError: name 'df' is not defined

# %%
df.reset_index(inplace=True) #set index again to int or numbers
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4079419278f0> in <module>
# ----> 1 df.reset_index(inplace=True) #set index again to int or numbers
#       2 df
#
# NameError: name 'df' is not defined
